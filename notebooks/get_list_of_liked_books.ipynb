# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

# %%
df_books = pd.read_csv("../data/raw/books_data.csv")

# %%
titles = pd.DataFrame(df_books["Title"])

# %%
titles
# Out:
#                                                     Title
# 0                          Its Only Art If Its Well Hung!
# 1                                Dr. Seuss: American Icon
# 2                   Wonderful Worship in Smaller Churches
# 3                           Whispers of the Wicked Saints
# 4       Nation Dance: Religion, Identity and Cultural ...
# ...                                                   ...
# 212399  The Orphan Of Ellis Island (Time Travel Advent...
# 212400                            Red Boots for Christmas
# 212401                                              Mamaw
# 212402                                  The Autograph Man
# 212403  Student's Solutions Manual for Johnson/Mowry's...
#
# [212404 rows x 1 columns]

# %%
print("Len: {}".format(len(df_books)))
df_books.isnull().sum()
# Out:
# Len: 212404
# Title                 1
# description       68442
# authors           31413
# image             52075
# previewLink       23836
# publisher         75886
# publishedDate     25305
# infoLink          23836
# categories        41199
# ratingsCount     162652
# dtype: int64

# %%
df_books.dropna(inplace=True)
print("Len: {}".format(len(df_books)))
# Out:
# Len: 40635

# %%
df_books.head()
# Out:
#                                                 Title  \
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 31  Voices from the Farm: Adventures in Community ...
# 33                            The Battleship Bismarck
# 42                            Tess and the Highlander
# 43   Beginner's Yoruba (Hippocrene Beginner's Series)
#
#                                           description  \
# 5   In The Church of Christ: A Biblical Ecclesiolo...
# 31  Twenty-five years ago, at the height of the co...
# 33  The Bismarck is perhaps the most famous – and ...
# 42  In 1543, on a windswept isle off of Scotland, ...
# 43  "Beginner's Yoruba" is now available with two ...
#
#                     authors  \
# 5      ['Everett Ferguson']
# 31          ['Rupert Fike']
# 33     ['Stefan Draminski']
# 42       ['May Mcgoldrick']
# 43  ['Kayode J. Fakinlede']
#
#                                                 image  \
# 5   http://books.google.com/books/content?id=kVqRa...
# 31  http://books.google.com/books/content?id=IjTAB...
# 33  http://books.google.com/books/content?id=nxttD...
# 42  http://books.google.com/books/content?id=VmCRS...
# 43  http://books.google.com/books/content?id=xLe4n...
#
#                                           previewLink  \
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 31  http://books.google.nl/books?id=IjTABgAAQBAJ&p...
# 33  http://books.google.nl/books?id=nxttDwAAQBAJ&p...
# 42  http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43  http://books.google.nl/books?id=xLe4nWzeSw0C&p...
#
#                      publisher publishedDate  \
# 5   Wm. B. Eerdmans Publishing          1996
# 31     Book Publishing Company    2012-08-21
# 33       Bloomsbury Publishing    2018-09-20
# 42              Harper Collins       2002-11
# 43            Hippocrene Books          2005
#
#                                              infoLink  \
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 31  https://play.google.com/store/books/details?id...
# 33  https://play.google.com/store/books/details?id...
# 42  http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43  http://books.google.nl/books?id=xLe4nWzeSw0C&d...
#
#                        categories  ratingsCount
# 5                    ['Religion']           5.0
# 31  ['Biography & Autobiography']           1.0
# 33                    ['History']           1.0
# 42           ['Juvenile Fiction']           2.0
# 43     ['Foreign Language Study']           1.0

# %%
df_books["ratingsCount"] = pd.to_numeric(df_books["ratingsCount"])

# %%
df_books
# Out:
#                                                     Title  \
# 5       The Church of Christ: A Biblical Ecclesiology ...
# 31      Voices from the Farm: Adventures in Community ...
# 33                                The Battleship Bismarck
# 42                                Tess and the Highlander
# 43       Beginner's Yoruba (Hippocrene Beginner's Series)
# ...                                                   ...
# 212374                                        Thin Within
# 212392  The Awakening and Selected Stories (Modern Lib...
# 212394                                       Final things
# 212399  The Orphan Of Ellis Island (Time Travel Advent...
# 212402                                  The Autograph Man
#
#                                               description  \
# 5       In The Church of Christ: A Biblical Ecclesiolo...
# 31      Twenty-five years ago, at the height of the co...
# 33      The Bismarck is perhaps the most famous – and ...
# 42      In 1543, on a windswept isle off of Scotland, ...
# 43      "Beginner's Yoruba" is now available with two ...
# ...                                                   ...
# 212374  I want to lose weight, but dieting just doesn'...
# 212392  WHEN IT FIRST APPEARED IN 1899, THE AWAKENING ...
# 212394  Grace's father believes in science and builds ...
# 212399  During a school trip to Ellis Island, Dominick...
# 212402  Alex-Li Tandem sells autographs. His business ...
#
#                                      authors  \
# 5                       ['Everett Ferguson']
# 31                           ['Rupert Fike']
# 33                      ['Stefan Draminski']
# 42                        ['May Mcgoldrick']
# 43                   ['Kayode J. Fakinlede']
# ...                                      ...
# 212374  ['Judy Halliday', 'Arthur Halliday']
# 212392                       ['Kate Chopin']
# 212394                      ['Jenny Offill']
# 212399                   ['Elvira Woodruff']
# 212402                       ['Zadie Smith']
#
#                                                     image  \
# 5       http://books.google.com/books/content?id=kVqRa...
# 31      http://books.google.com/books/content?id=IjTAB...
# 33      http://books.google.com/books/content?id=nxttD...
# 42      http://books.google.com/books/content?id=VmCRS...
# 43      http://books.google.com/books/content?id=xLe4n...
# ...                                                   ...
# 212374  http://books.google.com/books/content?id=L_YV_...
# 212392  http://books.google.com/books/content?id=TDK4u...
# 212394  http://books.google.com/books/content?id=UbSFB...
# 212399  http://books.google.com/books/content?id=J7M-N...
# 212402  http://books.google.com/books/content?id=JM6YV...
#
#                                               previewLink  \
# 5       http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 31      http://books.google.nl/books?id=IjTABgAAQBAJ&p...
# 33      http://books.google.nl/books?id=nxttDwAAQBAJ&p...
# 42      http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43      http://books.google.nl/books?id=xLe4nWzeSw0C&p...
# ...                                                   ...
# 212374  http://books.google.com/books?id=L_YV_kuQwk8C&...
# 212392  http://books.google.com/books?id=TDK4u5Fl2D8C&...
# 212394  http://books.google.com/books?id=UbSFBAAAQBAJ&...
# 212399  http://books.google.com/books?id=J7M-NwAACAAJ&...
# 212402  http://books.google.com/books?id=JM6YVPx_clMC&...
#
#                          publisher publishedDate  \
# 5       Wm. B. Eerdmans Publishing          1996
# 31         Book Publishing Company    2012-08-21
# 33           Bloomsbury Publishing    2018-09-20
# 42                  Harper Collins       2002-11
# 43                Hippocrene Books          2005
# ...                            ...           ...
# 212374               Thomas Nelson    2005-04-17
# 212392       Library of Alexandria          2003
# 212394                     Vintage    2015-03-17
# 212399       Scholastic Paperbacks    2000-06-01
# 212402                     Vintage    2003-08-12
#
#                                                  infoLink  \
# 5       http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 31      https://play.google.com/store/books/details?id...
# 33      https://play.google.com/store/books/details?id...
# 42      http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43      http://books.google.nl/books?id=xLe4nWzeSw0C&d...
# ...                                                   ...
# 212374  https://play.google.com/store/books/details?id...
# 212392  https://play.google.com/store/books/details?id...
# 212394  https://play.google.com/store/books/details?id...
# 212399  http://books.google.com/books?id=J7M-NwAACAAJ&...
# 212402  https://play.google.com/store/books/details?id...
#
#                            categories  ratingsCount
# 5                        ['Religion']           5.0
# 31      ['Biography & Autobiography']           1.0
# 33                        ['History']           1.0
# 42               ['Juvenile Fiction']           2.0
# 43         ['Foreign Language Study']           1.0
# ...                               ...           ...
# 212374           ['Health & Fitness']           9.0
# 212392                   ['Adultery']           2.0
# 212394                    ['Fiction']           4.0
# 212399           ['Juvenile Fiction']           2.0
# 212402                    ['Fiction']          19.0
#
# [40635 rows x 10 columns]

# %%
def rename_title(df, title_column_name):
    df["mod_title"] = df[title_column_name].str.lower().replace("[^a-z0-9 ]", "", regex=True).str.replace("\s+", " ", regex=True)
    #.replace("[^a-z0-9]", "", regex=True)
    #.str.replace("\s+", " ", regex=True)
    return df

# %%
df_books = rename_title(df_books, "Title")
df_books.head()
# Out:
#                                                 Title  \
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 31  Voices from the Farm: Adventures in Community ...
# 33                            The Battleship Bismarck
# 42                            Tess and the Highlander
# 43   Beginner's Yoruba (Hippocrene Beginner's Series)
#
#                                           description  \
# 5   In The Church of Christ: A Biblical Ecclesiolo...
# 31  Twenty-five years ago, at the height of the co...
# 33  The Bismarck is perhaps the most famous – and ...
# 42  In 1543, on a windswept isle off of Scotland, ...
# 43  "Beginner's Yoruba" is now available with two ...
#
#                     authors  \
# 5      ['Everett Ferguson']
# 31          ['Rupert Fike']
# 33     ['Stefan Draminski']
# 42       ['May Mcgoldrick']
# 43  ['Kayode J. Fakinlede']
#
#                                                 image  \
# 5   http://books.google.com/books/content?id=kVqRa...
# 31  http://books.google.com/books/content?id=IjTAB...
# 33  http://books.google.com/books/content?id=nxttD...
# 42  http://books.google.com/books/content?id=VmCRS...
# 43  http://books.google.com/books/content?id=xLe4n...
#
#                                           previewLink  \
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 31  http://books.google.nl/books?id=IjTABgAAQBAJ&p...
# 33  http://books.google.nl/books?id=nxttDwAAQBAJ&p...
# 42  http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43  http://books.google.nl/books?id=xLe4nWzeSw0C&p...
#
#                      publisher publishedDate  \
# 5   Wm. B. Eerdmans Publishing          1996
# 31     Book Publishing Company    2012-08-21
# 33       Bloomsbury Publishing    2018-09-20
# 42              Harper Collins       2002-11
# 43            Hippocrene Books          2005
#
#                                              infoLink  \
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 31  https://play.google.com/store/books/details?id...
# 33  https://play.google.com/store/books/details?id...
# 42  http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43  http://books.google.nl/books?id=xLe4nWzeSw0C&d...
#
#                        categories  ratingsCount  \
# 5                    ['Religion']           5.0
# 31  ['Biography & Autobiography']           1.0
# 33                    ['History']           1.0
# 42           ['Juvenile Fiction']           2.0
# 43     ['Foreign Language Study']           1.0
#
#                                             mod_title
# 5   the church of christ a biblical ecclesiology f...
# 31  voices from the farm adventures in community l...
# 33                            the battleship bismarck
# 42                            tess and the highlander
# 43       beginners yoruba hippocrene beginners series

# %%
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(df_books["mod_title"])

# %%
def make_clickable(val):
    return '<a target="-blank" href="{}">Google</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

def search(query, vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = df_books.iloc[indices]
    results
    results = results.sort_values("ratingsCount", ascending=False)
    results
    return results.head(5).style.format({'infoLink': make_clickable, 'image': show_image})

# %%
search("Harry Potter", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35e7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35e7a_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_35e7a_level0_col1" class="col_heading level0 col1" >description</th>
#       <th id="T_35e7a_level0_col2" class="col_heading level0 col2" >authors</th>
#       <th id="T_35e7a_level0_col3" class="col_heading level0 col3" >image</th>
#       <th id="T_35e7a_level0_col4" class="col_heading level0 col4" >previewLink</th>
#       <th id="T_35e7a_level0_col5" class="col_heading level0 col5" >publisher</th>
#       <th id="T_35e7a_level0_col6" class="col_heading level0 col6" >publishedDate</th>
#       <th id="T_35e7a_level0_col7" class="col_heading level0 col7" >infoLink</th>
#       <th id="T_35e7a_level0_col8" class="col_heading level0 col8" >categories</th>
#       <th id="T_35e7a_level0_col9" class="col_heading level0 col9" >ratingsCount</th>
#       <th id="T_35e7a_level0_col10" class="col_heading level0 col10" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35e7a_level0_row0" class="row_heading level0 row0" >62999</th>
#       <td id="T_35e7a_row0_col0" class="data row0 col0" >Harry Potter and the Chamber of Secrets</td>
#       <td id="T_35e7a_row0_col1" class="data row0 col1" >Witchcraft, wizardry - fiction.</td>
#       <td id="T_35e7a_row0_col2" class="data row0 col2" >['J. K. Rowling']</td>
#       <td id="T_35e7a_row0_col3" class="data row0 col3" ><img src="http://books.google.com/books/content?id=nmXTy4FPfcwC&printsec=frontcover&img=1&zoom=1&source=gbs_api" width=50></img></td>
#       <td id="T_35e7a_row0_col4" class="data row0 col4" >http://books.google.com/books?id=nmXTy4FPfcwC&q=Harry+Potter+and+the+Chamber+of+Secrets&dq=Harry+Potter+and+the+Chamber+of+Secrets&hl=&cd=1&source=gbs_api</td>
#       <td id="T_35e7a_row0_col5" class="data row0 col5" >Raincoast Books</td>
#       <td id="T_35e7a_row0_col6" class="data row0 col6" >1999</td>
#       <td id="T_35e7a_row0_col7" class="data row0 col7" ><a target="-blank" href="http://books.google.com/books?id=nmXTy4FPfcwC&dq=Harry+Potter+and+the+Chamber+of+Secrets&hl=&source=gbs_api">Google</a></td>
#       <td id="T_35e7a_row0_col8" class="data row0 col8" >['Juvenile Fiction']</td>
#       <td id="T_35e7a_row0_col9" class="data row0 col9" >14.000000</td>
#       <td id="T_35e7a_row0_col10" class="data row0 col10" >harry potter and the chamber of secrets</td>
#     </tr>
#     <tr>
#       <th id="T_35e7a_level0_row1" class="row_heading level0 row1" >31810</th>
#       <td id="T_35e7a_row1_col0" class="data row1 col0" >The Irresistible Rise of Harry Potter</td>
#       <td id="T_35e7a_row1_col1" class="data row1 col1" >Blake's examination of the Potter phenomenon raises serious questions about the condition of the publishing industry, filmmaking, and the ways in which the Potter consumer campaign has changed ideas about literature and reading.</td>
#       <td id="T_35e7a_row1_col2" class="data row1 col2" >['Andrew Blake']</td>
#       <td id="T_35e7a_row1_col3" class="data row1 col3" ><img src="http://books.google.com/books/content?id=Aaug_RnI-xQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api" width=50></img></td>
#       <td id="T_35e7a_row1_col4" class="data row1 col4" >http://books.google.com/books?id=Aaug_RnI-xQC&printsec=frontcover&dq=The+Irresistible+Rise+of+Harry+Potter&hl=&cd=1&source=gbs_api</td>
#       <td id="T_35e7a_row1_col5" class="data row1 col5" >Verso</td>
#       <td id="T_35e7a_row1_col6" class="data row1 col6" >2002</td>
#       <td id="T_35e7a_row1_col7" class="data row1 col7" ><a target="-blank" href="http://books.google.com/books?id=Aaug_RnI-xQC&dq=The+Irresistible+Rise+of+Harry+Potter&hl=&source=gbs_api">Google</a></td>
#       <td id="T_35e7a_row1_col8" class="data row1 col8" >['Literary Criticism']</td>
#       <td id="T_35e7a_row1_col9" class="data row1 col9" >4.000000</td>
#       <td id="T_35e7a_row1_col10" class="data row1 col10" >the irresistible rise of harry potter</td>
#     </tr>
#     <tr>
#       <th id="T_35e7a_level0_row2" class="row_heading level0 row2" >170495</th>
#       <td id="T_35e7a_row2_col0" class="data row2 col0" >Harry Potter Manuscript Book</td>
#       <td id="T_35e7a_row2_col1" class="data row2 col1" >'As someone who respects comprehensive research, I am in awe of the level of detail and amount of time Philip Errington has dedicated to this slavishly thorough and somewhat mind-boggling bibliography.' J. K. Rowling This is the definitive bibliography of the writings of J. K. Rowling. In addition to complete bibliographic details of each edition of all her books, pamphlets and original contributions to published works, there is detailed information on the publishing history of her work, including fascinating extracts from correspondence, and information on Rowling at auction. This will be the first source on Rowling consulted by textual scholars, book dealers and collectors, auction houses, critics and researchers. The aim of the book is to record fact and dispel rumour on the fascinating publishing history of the Harry Potter series.</td>
#       <td id="T_35e7a_row2_col2" class="data row2 col2" >['Philip W. Errington']</td>
#       <td id="T_35e7a_row2_col3" class="data row2 col3" ><img src="http://books.google.com/books/content?id=H8buBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api" width=50></img></td>
#       <td id="T_35e7a_row2_col4" class="data row2 col4" >http://books.google.com/books?id=H8buBQAAQBAJ&printsec=frontcover&dq=Harry+Potter+Manuscript+Book&hl=&cd=1&source=gbs_api</td>
#       <td id="T_35e7a_row2_col5" class="data row2 col5" >Bloomsbury Publishing</td>
#       <td id="T_35e7a_row2_col6" class="data row2 col6" >2015-02-26</td>
#       <td id="T_35e7a_row2_col7" class="data row2 col7" ><a target="-blank" href="http://books.google.com/books?id=H8buBQAAQBAJ&dq=Harry+Potter+Manuscript+Book&hl=&source=gbs_api">Google</a></td>
#       <td id="T_35e7a_row2_col8" class="data row2 col8" >['Literary Criticism']</td>
#       <td id="T_35e7a_row2_col9" class="data row2 col9" >2.000000</td>
#       <td id="T_35e7a_row2_col10" class="data row2 col10" >harry potter manuscript book</td>
#     </tr>
#     <tr>
#       <th id="T_35e7a_level0_row3" class="row_heading level0 row3" >36776</th>
#       <td id="T_35e7a_row3_col0" class="data row3 col0" >Harry Potter and The Sorcerer's Stone</td>
#       <td id="T_35e7a_row3_col1" class="data row3 col1" >Celebrate 20 years of Harry Potter magic! Harry Potter has never even heard of Hogwarts when the letters start dropping on the doormat at number four, Privet Drive. Addressed in green ink on yellowish parchment with a purple seal, they are swiftly confiscated by his grisly aunt and uncle. Then, on Harry's eleventh birthday, a great beetle-eyed giant of a man called Rubeus Hagrid bursts in with some astonishing news: Harry Potter is a wizard, and he has a place at Hogwarts School of Witchcraft and Wizardry. An incredible adventure is about to begin!These new editions of the classic and internationally bestselling, multi-award-winning series feature instantly pick-up-able new jackets by Jonny Duddle, with huge child appeal, to bring Harry Potter to the next generation of readers. It's time to PASS THE MAGIC ON ...</td>
#       <td id="T_35e7a_row3_col2" class="data row3 col2" >['J. K. Rowling']</td>
#       <td id="T_35e7a_row3_col3" class="data row3 col3" ><img src="http://books.google.com/books/content?id=HksgDQAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api" width=50></img></td>
#       <td id="T_35e7a_row3_col4" class="data row3 col4" >http://books.google.com/books?id=HksgDQAAQBAJ&dq=Harry+Potter+and+The+Sorcerer%27s+Stone&hl=&cd=1&source=gbs_api</td>
#       <td id="T_35e7a_row3_col5" class="data row3 col5" >Bloomsbury Publishing</td>
#       <td id="T_35e7a_row3_col6" class="data row3 col6" >2014-01-09</td>
#       <td id="T_35e7a_row3_col7" class="data row3 col7" ><a target="-blank" href="http://books.google.com/books?id=HksgDQAAQBAJ&dq=Ha

# %%
liked_books = ["81605", "62999", "36776", "60730", "33908"]
